# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing dataset in excel format

# %%
data=pd.read_excel(r"C:\Users\Pearl\Downloads\data1.xls")
# Out:
#                   Country Name Country Code                     Region  \
# 0                        Aruba          ABW  Latin America & Caribbean
# 1  Africa Eastern and Southern          AFE                        NaN
# 2                  Afghanistan          AFG                 South Asia
# 3   Africa Western and Central          AFW                        NaN
# 4                       Angola          AGO         Sub-Saharan Africa
#
#            IncomeGroup     Indicator Name Indicator Code         1960  \
# 0          High income  Population, total    SP.POP.TOTL      54608.0
# 1                  NaN  Population, total    SP.POP.TOTL  130692579.0
# 2           Low income  Population, total    SP.POP.TOTL    8622466.0
# 3                  NaN  Population, total    SP.POP.TOTL   97256290.0
# 4  Lower middle income  Population, total    SP.POP.TOTL    5357195.0
#
#           1961         1962         1963  ...         2014         2015  \
# ...

# %% [markdown]
# Data Overview

# %%
data.head()
# Out:
#                   Country Name Country Code                     Region  \
# 0                        Aruba          ABW  Latin America & Caribbean
# 1  Africa Eastern and Southern          AFE                        NaN
# 2                  Afghanistan          AFG                 South Asia
# 3   Africa Western and Central          AFW                        NaN
# 4                       Angola          AGO         Sub-Saharan Africa
#
#            IncomeGroup     Indicator Name Indicator Code         1960  \
# 0          High income  Population, total    SP.POP.TOTL      54608.0
# 1                  NaN  Population, total    SP.POP.TOTL  130692579.0
# 2           Low income  Population, total    SP.POP.TOTL    8622466.0
# 3                  NaN  Population, total    SP.POP.TOTL   97256290.0
# 4  Lower middle income  Population, total    SP.POP.TOTL    5357195.0
#
#           1961         1962         1963  ...         2014         2015  \
# ...

# %%
data.tail()
# Out:
#      Country Name Country Code                      Region  \
# 261        Kosovo          XKX  Middle East & North Africa
# 262   Yemen, Rep.          YEM          Sub-Saharan Africa
# 263  South Africa          ZAF          Sub-Saharan Africa
# 264        Zambia          ZMB          Sub-Saharan Africa
# 265      Zimbabwe          ZWE                         NaN
#
#              IncomeGroup     Indicator Name Indicator Code        1960  \
# 261           Low income  Population, total    SP.POP.TOTL    947000.0
# 262  Upper middle income  Population, total    SP.POP.TOTL   5542459.0
# 263  Lower middle income  Population, total    SP.POP.TOTL  16520441.0
# 264  Lower middle income  Population, total    SP.POP.TOTL   3119430.0
# 265                  NaN  Population, total    SP.POP.TOTL   3806310.0
#
#            1961        1962        1963  ...        2014        2015  \
# 261    966000.0    994000.0   1022000.0  ...   1812771.0   1788196.0
# ...

# %%
data.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172860e+08  1.188956e+08  1.210661e+08  1.237484e+08  1.264530e+08
# std    3.695500e+08  3.740958e+08  3.808121e+08  3.895098e+08  3.982497e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291965e+08  1.320558e+08  1.349134e+08  1.378513e+08  1.408944e+08
# ...

# %%
data.shape
# Out:
# (266, 70)

# %%
data.dtypes
# Out:
# Country Name       object
# Country Code       object
# Region             object
# IncomeGroup        object
# Indicator Name     object
#                    ...
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# 2023              float64
# Length: 70, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Region          217 non-null    object
#  3   IncomeGroup     216 non-null    object
#  4   Indicator Name  266 non-null    object
#  5   Indicator Code  266 non-null    object
#  6   1960            264 non-null    float64
#  7   1961            264 non-null    float64
#  8   1962            264 non-null    float64
#  9   1963            264 non-null    float64
#  10  1964            264 non-null    float64
#  11  1965            264 non-null    float64
#  12  1966            264 non-null    float64
#  13  1967            264 non-null    float64
#  14  1968            264 non-null    float64
#  15  1969            264 non-null    float64
#  16  1970            264 non-null    float64
# ...

# %%
data.isna().sum()
# Out:
# Country Name        0
# Country Code        0
# Region             49
# IncomeGroup        50
# Indicator Name      0
#                  ...
# 2019                1
# 2020                1
# 2021                1
# 2022                1
# 2023              266
# Length: 70, dtype: int64

# %% [markdown]
# Plotting histogram using seaborn library

# %%
sns.histplot(data = data, x = "Region", kde = True)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Latin America & Caribbean'),
#   Text(1, 0, 'South Asia'),
#   Text(2, 0, 'Sub-Saharan Africa'),
#   Text(3, 0, 'Europe & Central Asia'),
#   Text(4, 0, 'Middle East & North Africa'),
#   Text(5, 0, 'East Asia & Pacific'),
#   Text(6, 0, 'North America')])

# %% [markdown]
# Plotting bar graph/chart using matplotlib library

# %%
region_counts = data['Region'].value_counts()

plt.figure(figsize=(10, 6))
region_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Region')
plt.ylabel('Number of Countries')
plt.title('Distribution of Countries by Region')
plt.xticks(rotation=45) 
plt.show()

# %%
# Sort countries by count in descending order
country_counts_sorted = country_counts.sort_values(ascending=False)

# Choose the top N countries to display (adjust N as needed)
top_n_countries = country_counts_sorted.index[:10]  # Display the top 10

# Filter data and counts for selected countries
filtered_data = data[data['Country Name'].isin(top_n_countries)]
filtered_counts = country_counts_sorted[top_n_countries]

# Create the bar chart
plt.bar(filtered_counts.index, filtered_counts.values)
plt.xlabel('Country Name')
plt.ylabel('Number of Countries')
plt.title('Top 10 Most Frequent Countries')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()
